# %%
from wsi_patching.writers.webdataset.webdataset_loader import WebDatasetLoader

# %%
wdl = WebDatasetLoader()
wdl_dl = wdl.get_dataloader()

# %%
for batch in wdl_dl:
    print(batch)
    break
# Out:
# [tensor([[[[0.8902, 0.8902, 0.8902,  ..., 0.8863, 0.8863, 0.8863],
#           [0.8902, 0.8902, 0.8902,  ..., 0.8863, 0.8863, 0.8863],
#           [0.8980, 0.8902, 0.8863,  ..., 0.8863, 0.8824, 0.8824],
#           ...,
#           [0.8941, 0.8941, 0.8941,  ..., 0.8863, 0.8902, 0.8902],
#           [0.8941, 0.8941, 0.8941,  ..., 0.8863, 0.8902, 0.8902],
#           [0.8941, 0.8941, 0.8941,  ..., 0.8863, 0.8902, 0.8902]],
#
#          [[0.8510, 0.8510, 0.8510,  ..., 0.8549, 0.8549, 0.8549],
#           [0.8510, 0.8510, 0.8510,  ..., 0.8549, 0.8549, 0.8549],
#           [0.8588, 0.8510, 0.8471,  ..., 0.8549, 0.8510, 0.8510],
#           ...,
#           [0.8549, 0.8549, 0.8549,  ..., 0.8549, 0.8588, 0.8588],
#           [0.8549, 0.8549, 0.8549,  ..., 0.8549, 0.8588, 0.8588],
#           [0.8549, 0.8549, 0.8549,  ..., 0.8549, 0.8588, 0.8588]],
#
#          [[0.8941, 0.8941, 0.8941,  ..., 0.8980, 0.8980, 0.8980],
#           [0.8941, 0.8941, 0.8941,  ..., 0.8980, 0.8980, 0.8980],
# ...

# %%
index = 0

# %%
import matplotlib.pyplot as plt

plt.imshow(batch[0][index].permute(1, 2, 0).numpy())
index += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.imshow(batch[0][index].permute(1, 2, 0).numpy())
#       4 index += 1
#
# IndexError: index 32 is out of bounds for dimension 0 with size 32
